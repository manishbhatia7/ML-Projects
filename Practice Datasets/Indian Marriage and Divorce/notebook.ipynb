# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('divorce.csv')

# %%
data.head()
# Out:
#   Unique ID  Marriage Duration (Years)  Age at Marriage Marriage Type  \
# 0       MD1                         39               29          Love
# 1       MD2                         29               34      Arranged
# 2       MD3                         15               34          Love
# 3       MD4                          8               27      Arranged
# 4       MD5                         21               34          Love
#
#   Education Level  Income Level (INR per month) Caste/Religion Urban/Rural  \
# 0       Secondary                        113464          Hindu       Rural
# 1    No Education                         18682           Jain       Rural
# 2    No Education                        159455         Muslim       Urban
# 3    Postgraduate                         63160           Jain       Urban
# 4       Secondary                         28666           Jain       Urban
#
#   Family Involvement  Children Divorce Status
# 0           Moderate         2             No
# ...

# %%
data=data.drop('Unique ID',axis=1)

# %%
data.columns
# Out:
# Index(['Marriage Duration (Years)', 'Age at Marriage', 'Marriage Type',
#        'Education Level', 'Income Level (INR per month)', 'Caste/Religion',
#        'Urban/Rural', 'Family Involvement', 'Children', 'Divorce Status'],
#       dtype='object')

# %%
cols_to_be_renamed={'Marriage Duration (Years)':'Marriage Duration','Age at Marriage':'Age','Income Level (INR per month)':'Income Per Month',
                    'Caste/Religion':'Religion','Urban/Rural':'Living Environment','Children':'No of Kids'}
data.rename(columns=cols_to_be_renamed,inplace=True)

# %%
data.head()
# Out:
#    Marriage Duration  Age Marriage Type Education Level  Income Per Month  \
# 0                 39   29          Love       Secondary            113464
# 1                 29   34      Arranged    No Education             18682
# 2                 15   34          Love    No Education            159455
# 3                  8   27      Arranged    Postgraduate             63160
# 4                 21   34          Love       Secondary             28666
#
#   Religion Living Environment Family Involvement  No of Kids Divorce Status
# 0    Hindu              Rural           Moderate           2             No
# 1     Jain              Rural           Moderate           0            Yes
# 2   Muslim              Urban           Moderate           4            Yes
# 3     Jain              Urban               High           1            Yes
# 4     Jain              Urban               High           1            Yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Marriage Duration   1200 non-null   int64
#  1   Age                 1200 non-null   int64
#  2   Marriage Type       1200 non-null   object
#  3   Education Level     1200 non-null   object
#  4   Income Per Month    1200 non-null   int64
#  5   Religion            1200 non-null   object
#  6   Living Environment  1200 non-null   object
#  7   Family Involvement  1200 non-null   object
#  8   No of Kids          1200 non-null   int64
#  9   Divorce Status      1200 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 93.9+ KB

# %%
data['Divorce Status'].value_counts(normalize=True)
# Out:
# Divorce Status
# No     0.688333
# Yes    0.311667
# Name: proportion, dtype: float64

# %%
sns.countplot(x='Divorce Status',data=data,hue='Divorce Status',legend=True)    
plt.show()

# %%
data['Income Per Month'].hist()
plt.show()

# %%
data.describe()
# Out:
#        Marriage Duration          Age  Income Per Month   No of Kids
# count        1200.000000  1200.000000        1200.00000  1200.000000
# mean           20.553333    26.055000      102353.21250     1.885833
# std            11.468512     4.891003       55761.10746     1.453580
# min             1.000000    18.000000        5287.00000     0.000000
# 25%            10.000000    22.000000       54522.00000     1.000000
# 50%            22.000000    26.000000      101888.50000     2.000000
# 75%            30.000000    30.000000      150568.75000     3.000000
# max            39.000000    34.000000      199999.00000     4.000000

# %%
sns.boxplot(x='Income Per Month',data=data,)
plt.show()

# %%
sns.countplot(x='Religion',data=data,orient='h')
plt.show()

# %%
sns.countplot(x='Marriage Type',hue='Divorce Status',data=data)
plt.show()

# %%
sns.countplot(x='Education Level',hue='Divorce Status',data=data)
plt.show()

# %%
sns.countplot(x='No of Kids',hue='Divorce Status',data=data)
plt.show()

# %%
sns.countplot(x='Living Environment',hue='Divorce Status',data=data)
plt.show()

# %%
sns.countplot(x='Family Involvement',hue='Divorce Status',data=data)
plt.show()

# %%
sns.countplot(x='Marriage Type',hue='Family Involvement',data=data)
plt.show()

# %%
pd.crosstab(data['Divorce Status'],data['Marriage Type'])
# Out:
# Marriage Type   Arranged  Love
# Divorce Status
# No                   427   399
# Yes                  199   175

# %%
pd.crosstab(data['Age'],data['Divorce Status']).sort_values(by='Yes',ascending=False)
# Out:
# Divorce Status  No  Yes
# Age
# 34              44   31
# 32              51   29
# 30              47   28
# 23              40   28
# 20              48   26
# 21              49   25
# 29              50   25
# 25              51   23
# 19              52   23
# 24              46   22
# 31              51   21
# 22              52   20
# 26              48   18
# 27              54   18
# 28              45   16
# 33              47   13
# 18              51    8

# %%
sns.scatterplot(x='Age',y='Income Per Month',data=data)
plt.show()
