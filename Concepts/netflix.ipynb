# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('netflix_data.csv')

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s2    Movie   7:19  Jorge Michel Grau
# 1      s3    Movie  23:59       Gilbert Chan
# 2      s4    Movie      9        Shane Acker
# 3      s5    Movie     21     Robert Luketic
# 4      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 4       July 1, 2017          2016         1
#
# ...

# %%
subset=df[df["type"] == "Movie"]

# %%
movie_1990s=subset[subset['release_year'] < 2000]

# %%
movie_1990s
# Out:
#      show_id   type                                title  \
# 6         s8  Movie                                  187
# 72      s106  Movie                  300 Miles to Heaven
# 106     s154  Movie                     A Bridge Too Far
# 117     s166  Movie                   A Clockwork Orange
# 118     s167  Movie                    A Dangerous Woman
# ...      ...    ...                                  ...
# 4722   s7629  Movie  Willy Wonka & the Chocolate Factory
# 4726   s7636  Movie                 Winter of Our Dreams
# 4746   s7682  Movie                           Wyatt Earp
# 4756   s7695  Movie                          Yaar Gaddar
# 4783   s7738  Movie                          Young Tiger
#
#                   director                                               cast  \
# 6           Kevin Reynolds  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 72          Maciej Dejczer  Krzysztof Stroiński, Andrzej Mellin, Adrianna ...
# ...

# %%
plt.figure(figsize=(20,10))
plt.hist(movie_1990s['duration'])
plt.xlabel('Movies')
plt.ylabel('Duration')
plt.show()

# %%
duration=100

# %%
movie_1990s_action=movie_1990s[movie_1990s['genre']=='Action']

# %%
movie_1990s_action
# Out:
#      show_id   type                title                     director  \
# 106     s154  Movie     A Bridge Too Far         Richard Attenborough
# 188     s268  Movie       Aakhri Adaalat                  Rajiv Mehra
# 271     s392  Movie  Alibaba Aur 40 Chor  Latif Faiziyev, Umesh Mehra
# 309     s447  Movie   Amar Akbar Anthony               Manmohan Desai
# 352     s508  Movie      Andaz Apna Apna            Rajkumar Santoshi
# ...      ...    ...                  ...                          ...
# 4456   s7163  Movie         Total Recall               Paul Verhoeven
# 4490   s7224  Movie             Trimurti                  Mukul Anand
# 4718   s7624  Movie       Wild Wild West             Barry Sonnenfeld
# 4746   s7682  Movie           Wyatt Earp              Lawrence Kasdan
# 4783   s7738  Movie          Young Tiger                       Mu Chu
#
#                                                    cast        country  \
# ...

# %%
(movie_1990s_action['duration'] < 90).sum()
# Out:
# 13
